# %%
year = '2024'

# %%
url_link = 'https://www.basketball-reference.com/leagues/NBA_{}_per_game.html'

# %%
url = url_link.format(year)

# %%
url
# Out:
# 'https://www.basketball-reference.com/leagues/NBA_2024_per_game.html'

# %%
years = [2020,2021,2022,2023,2024] 
url_link = 'https://www.basketball-reference.com/leagues/NBA_{}_per_game.html'

# %%
for year in years:
    url = url_link.format(year)
    print(url)
# Out:
# https://www.basketball-reference.com/leagues/NBA_2020_per_game.html
# https://www.basketball-reference.com/leagues/NBA_2021_per_game.html
# https://www.basketball-reference.com/leagues/NBA_2022_per_game.html
# https://www.basketball-reference.com/leagues/NBA_2023_per_game.html
# https://www.basketball-reference.com/leagues/NBA_2024_per_game.html

# %%
import pandas as pd

# %%
# Read HTML page using pd
df = pd.read_html(url, header = 0)

# %%
df
# Out:
# [      Rk            Player   Pos Age   Tm   G  GS    MP   FG   FGA  ...   FT%  \
#  0      1  Precious Achiuwa  C-PF  24  TOT  46   7  20.4  3.2   6.5  ...  .625
#  1      1  Precious Achiuwa     C  24  TOR  25   0  17.5  3.1   6.8  ...  .571
#  2      1  Precious Achiuwa    PF  24  NYK  21   7  23.9  3.2   6.1  ...  .786
#  3      2       Bam Adebayo     C  26  MIA  43  43  34.5  7.6  15.0  ...  .780
#  4      3      Ochai Agbaji    SG  23  TOT  52  10  19.7  2.1   5.0  ...  .739
#  ..   ...               ...   ...  ..  ...  ..  ..   ...  ...   ...  ...   ...
#  650  533    Thaddeus Young    PF  35  TOR  23   6  15.2  2.3   3.8  ...  .417
#  651  534        Trae Young    PG  25  ATL  48  48  36.6  8.5  19.6  ...  .855
#  652  535    Omer Yurtseven     C  25  UTA  28   6   9.5  1.4   2.9  ...  .545
#  653  536       Cody Zeller     C  31  NOP  36   0   8.0  0.6   1.5  ...  .600
#  654  537       Ivica Zubac     C  26  LAC  41  41  26.6  5.1   7.8  ...  .655
#
# ...

# %%
# table len
len(df)
# Out:
# 1

# %%
# select first table
#df[0]
df[0:20]
# Out:
# [      Rk            Player   Pos Age   Tm   G  GS    MP   FG   FGA  ...   FT%  \
#  0      1  Precious Achiuwa  C-PF  24  TOT  46   7  20.4  3.2   6.5  ...  .625
#  1      1  Precious Achiuwa     C  24  TOR  25   0  17.5  3.1   6.8  ...  .571
#  2      1  Precious Achiuwa    PF  24  NYK  21   7  23.9  3.2   6.1  ...  .786
#  3      2       Bam Adebayo     C  26  MIA  43  43  34.5  7.6  15.0  ...  .780
#  4      3      Ochai Agbaji    SG  23  TOT  52  10  19.7  2.1   5.0  ...  .739
#  ..   ...               ...   ...  ..  ...  ..  ..   ...  ...   ...  ...   ...
#  650  533    Thaddeus Young    PF  35  TOR  23   6  15.2  2.3   3.8  ...  .417
#  651  534        Trae Young    PG  25  ATL  48  48  36.6  8.5  19.6  ...  .855
#  652  535    Omer Yurtseven     C  25  UTA  28   6   9.5  1.4   2.9  ...  .545
#  653  536       Cody Zeller     C  31  NOP  36   0   8.0  0.6   1.5  ...  .600
#  654  537       Ivica Zubac     C  26  LAC  41  41  26.6  5.1   7.8  ...  .655
#
# ...

# %%
df2024 = df[0]

# %%
# Data Cleaning - here table column name is duplicating in rows
df2024[df2024.Age == 'Age']
# Out:
#      Rk  Player  Pos  Age  Tm  G  GS  MP  FG  FGA  ...  FT%  ORB  DRB  TRB  \
# 28   Rk  Player  Pos  Age  Tm  G  GS  MP  FG  FGA  ...  FT%  ORB  DRB  TRB
# 61   Rk  Player  Pos  Age  Tm  G  GS  MP  FG  FGA  ...  FT%  ORB  DRB  TRB
# 84   Rk  Player  Pos  Age  Tm  G  GS  MP  FG  FGA  ...  FT%  ORB  DRB  TRB
# 111  Rk  Player  Pos  Age  Tm  G  GS  MP  FG  FGA  ...  FT%  ORB  DRB  TRB
# 132  Rk  Player  Pos  Age  Tm  G  GS  MP  FG  FGA  ...  FT%  ORB  DRB  TRB
# 157  Rk  Player  Pos  Age  Tm  G  GS  MP  FG  FGA  ...  FT%  ORB  DRB  TRB
# 182  Rk  Player  Pos  Age  Tm  G  GS  MP  FG  FGA  ...  FT%  ORB  DRB  TRB
# 207  Rk  Player  Pos  Age  Tm  G  GS  MP  FG  FGA  ...  FT%  ORB  DRB  TRB
# 228  Rk  Player  Pos  Age  Tm  G  GS  MP  FG  FGA  ...  FT%  ORB  DRB  TRB
# 251  Rk  Player  Pos  Age  Tm  G  GS  MP  FG  FGA  ...  FT%  ORB  DRB  TRB
# 272  Rk  Player  Pos  Age  Tm  G  GS  MP  FG  FGA  ...  FT%  ORB  DRB  TRB
# ...

# %%
len(df2024[df2024.Age == 'Age'])
# Out:
# 26

# %%
df = df2024.drop(df2024[df2024.Age == 'Age'].index)

# %%
df.shape
# Out:
# (629, 30)

# %%
# Exploratory Data Analysis
import seaborn as sns

# %%
sns.distplot(df.PTS, kde=False, color='blue')
# Out:
# <AxesSubplot:xlabel='PTS'>

# %%
sns.distplot(df.PTS, kde=False, color='blue', hist_kws=dict(edgecolor="red", linewidth=2))
# Out:
# <AxesSubplot:xlabel='PTS'>

# %%
sns.distplot(df.PTS, kde=False, hist_kws=dict(edgecolor="red", linewidth=2), color='orange')
# Out:
# <AxesSubplot:xlabel='PTS'>
